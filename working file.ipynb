# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

import json
from pandas.io.json import json_normalize

# %%
# get_files function from previous lesson
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
review_files = get_files('data/reviews/')
filepath = review_files[0]
f = open(filepath)
js = json.load(f)
df = pd.DataFrame(js['reviews'])
df['appid'] = os.path.basename(os.path.dirname(filepath))
df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
df.head()

# %%
reviews_data = df[ ['recommendationid', 'appid', 'language', 'review', 'timestamp_created',
                        'timestamp_updated', 'voted_up', 'votes_up', 'votes_funny', 'weighted_vote_score',
                        'comment_count', 'steam_purchase', 'received_for_free', 'written_during_early_access'] ]
reviews_data = reviews_data.values[0].tolist()
print(reviews_data)

# %%
review_files = get_files('data/reviews/')
filepath = review_files[0]
f = open(filepath)
js = json.load(f)
df = json_normalize(js['reviews'])
df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
df['appid'] = os.path.basename(os.path.dirname(filepath))
df.head()

# %%
review_files = get_files('data/reviews/')
filepath = review_files[0]
f = open(filepath)
js = json.load(f)
df = json_normalize(js['reviews'])
df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
df['appid'] = os.path.basename(os.path.dirname(filepath))
review_authors_data = df[ ['author.steamid', 'author.num_games_owned', 'author.num_reviews', 'author.playtime_forever',
                            'author.playtime_last_two_weeks', 'author.playtime_at_review', 'author.last_played'] ]
review_authors_data = review_authors_data.values[0].tolist()
print(review_authors_data)

# %%
game_files = get_files('data/reviews/')
filepath = review_files[0]
f = open(filepath)
js = json.load(f)
df = json_normalize(js['reviews'])
df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
df['appid'] = os.path.basename(os.path.dirname(filepath))
review_authors_data = df[ ['author.steamid', 'author.num_games_owned', 'author.num_reviews', 'author.playtime_forever',
                            'author.playtime_last_two_weeks', 'author.playtime_at_review', 'author.last_played'] ]
review_authors_data = review_authors_data.values[0].tolist()
print(review_authors_data)

# %%
df = pd.read_json('data/steam_spy_detailed.json', orient='index')
df.head()
#df.to_csv('data/steam_spy_detailed_csv.csv')
#df.shape[0]

# %%
#df_csv = pd.read_csv('data/steam_spy_detailed.csv')
#df_csv = df_csv[ df_csv[ 'appid' ] == 10 ]
f = open('data/steam_spy_detailed.json')
js = json.load(f)
df = json_normalize(js)
df.head()

# %%
game_data = df_csv[ ['appid', 'name', 'developer', 'publisher', 'positive', 'negative', 'owners',
                     'average_forever', 'average_2weeks', 'median_forever', 'median_2weeks', 'languages'] ]
game_data = game_data.values[0].tolist()
print(game_data)

# %%
def CustomParser(data):
    import json
    j1 = json.loads(data)
    return j1

# %%
df = pd.read_csv('data/games/steam_spy_detailed.csv')
game_data = df[ ['appid', 'name', 'developer', 'publisher', 'positive', 'negative', 'owners',
                'average_forever', 'average_2weeks', 'median_forever', 'median_2weeks', 'languages'] ]
game_data.dropna(subset=['name', 'developer', 'languages'], inplace=True)
game_data.head()

# %%
f = open('data/reviews/50/416F4A77395A5753692F30436459505768774D3D.json')
js = json.load(f)
df = json_normalize(js['reviews'])
df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
#df['appid'] = os.path.basename(os.path.dirname(filepath))

# insert reviews record
reviews_data = df[ ['timestamp_created', 'timestamp_updated',
                    'comment_count', 'steam_purchase', 'written_during_early_access'] ]
reviews_data = reviews_data.values[4].tolist()

# %%
print(reviews_data)

# %%
f = open('data/reviews/10/416F4A342B2B663375766F43633454673667493D.json')
js = json.load(f)
#df = json_normalize(js, record_path=['reviews'], meta=['num_reviews', 'query_summary'], errors='ignore')
df = json_normalize(js['reviews'], meta=['num_reviews'])
#df = df[ df[ 'query_summary.num_reviews' ] > 0 ]
#df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
#df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
#df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
#df['appid'] = os.path.basename(os.path.dirname(filepath))
df.head()
#print(js)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import glob as glob


inp_dir = Path('/data/reviews') 

for file in inp_dir.glob('*.json'):
    f = open(file)
    js = json.load(f)
    df = json_normalize(js['reviews'])
    df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
    df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
    df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
    if 'timestamp_created' not in df.columns:
        print('filename: ' + str(file))
        break
    df['timestamp_created'] = df['timestamp_created'].replace(np.nan, 0.01)
    df.to_csv(file,index=False)
print(df)

# %%
# This python script repurposed from 'Data Modelling with Postgres' activity

import psycopg2
from sql_queries import create_table_queries, drop_table_queries


def create_database():
    """
    - Creates and connects to the steam_reviews db
    - Returns the connection and cursor to steam_reviews db
    """
    
    # connect to default database
    conn = psycopg2.connect("host=127.0.0.1 dbname=studentdb user=student password=student")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    # create steam_reviews database with UTF8 encoding
    cur.execute("DROP DATABASE IF EXISTS steam_reviews")
    cur.execute("CREATE DATABASE steam_reviews WITH ENCODING 'utf8' TEMPLATE template0")

    # close connection to default database
    conn.close()    
    
    # connect to steam_reviews database
    conn = psycopg2.connect("host=127.0.0.1 dbname=steam_reviews user=student password=student")
    cur = conn.cursor()
    
    return cur, conn


def drop_tables(cur, conn):
    """
    Drops each table using the queries in `drop_table_queries` list.
    """
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()


def create_tables(cur, conn):
    """
    Creates each table using the queries in `create_table_queries` list. 
    """
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()


def main():
    """
    - Drops (if exists) and Creates the steam_reviews database. 
    
    - Establishes connection with the steam_reviews database and gets
    cursor to it.  
    
    - Drops all the tables.  
    
    - Creates all tables needed. 
    
    - Finally, closes the connection. 
    """
    cur, conn = create_database()
    
    drop_tables(cur, conn)
    create_tables(cur, conn)

    conn.close()


if __name__ == "__main__":
    main()

# %%
# repurposed from 'Data Modelling with Postgres' activity

import os
import glob
import psycopg2
import pandas as pd
import json
from pandas.io.json import json_normalize
from sql_queries import *


def process_games_file(cur, filepath):
    """
    This function processes the 'steam_spy_detailed.csv' file whose filepath has been provided as an arugment.
    It extracts the game information in order to store it into the games table.
    Then it extracts the game tag information in order to store it into the game_tags table.

    INPUTS: 
    * cur the cursor variable
    * filepath the file path to the song file
    """
    # open games file
    df = pd.read_csv(filepath)

    # insert games record
    game_data = df[ ['appid', 'name', 'developer', 'publisher', 'positive', 'negative', 'owners',
                     'average_forever', 'average_2weeks', 'median_forever', 'median_2weeks', 'languages'] ]
    game_data.dropna(subset=['name', 'developer', 'languages'], inplace=True)

    for i, row in game_data.iterrows():
        cur.execute(games_table_insert, row)

def process_reviews_file(cur, filepath):
    """
    This function processes a reviews file whose filepath has been provided as an argument.
    It converts epoch timestamps to datetime and then prepares to insert records into the reviews and review_authors tables.
    """
    # open reviews file
    f = open(filepath)
    js = json.load(f)
    df = json_normalize(js['reviews'])
    df['timestamp_created'] = pd.to_datetime(df[ 'timestamp_created' ], unit = 's').apply(str)
    df['timestamp_updated'] = pd.to_datetime(df[ 'timestamp_updated' ], unit = 's').apply(str)
    df['author.last_played'] = pd.to_datetime(df[ 'author.last_played' ], unit = 's').apply(str)
    df['appid'] = os.path.basename(os.path.dirname(filepath))

    # insert reviews record
    reviews_data = df[ ['recommendationid', 'appid', 'author.steamid', 'language', 'review', 'timestamp_created',
                        'timestamp_updated', 'voted_up', 'votes_up', 'votes_funny', 'weighted_vote_score',
                        'comment_count', 'steam_purchase', 'received_for_free', 'written_during_early_access'] ]

    for i, row in reviews_data.iterrows():
        cur.execute(reviews_table_insert, row)

    # insert review_authors record
    review_authors_data = df[ ['author.steamid', 'recommendationid', 'author.num_games_owned',
                               'author.num_reviews', 'author.playtime_forever', 'author.playtime_last_two_weeks',
                               'author.playtime_at_review', 'author.last_played'] ]

    for i, row in review_authors_data.iterrows():
        cur.execute(review_authors_table_insert, row)

def process_data(cur, conn, filepath, filetype, func):
    """
    This procedure iterates through all the files that need to be processed,
    and prints out a status/progress message.
    """
    # get all files matching extension from directory
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root, filetype))
        for f in files :
            all_files.append(os.path.abspath(f))

    # get total number of files found
    num_files = len(all_files)
    print('{} files found in {}'.format(num_files, filepath))

    # iterate over files and process
    for i, datafile in enumerate(all_files, 1):
        func(cur, datafile)
        conn.commit()
        print('{}/{} files processed.'.format(i, num_files))

def main():
    """
    This procedure connects to the steam_reviews database and executes the functions defined above.
    """
    conn = psycopg2.connect("host=127.0.0.1 dbname=steam_reviews user=student password=student")
    cur = conn.cursor()

    #process_data(cur, conn, filepath='data/games', filetype='*.csv', func=process_games_file)
    process_data(cur, conn, filepath='data/reviews', filetype='*.json', func=process_reviews_file)

    conn.close()


if __name__ == "__main__":
    main()
# Out:
# 20126 files found in data/reviews
# 1/20126 files processed.
# 2/20126 files processed.
# 3/20126 files processed.
# 4/20126 files processed.
# 5/20126 files processed.
# 6/20126 files processed.
# 7/20126 files processed.
# 8/20126 files processed.
# 9/20126 files processed.
# 10/20126 files processed.
# 11/20126 files processed.
# 12/20126 files processed.
# 13/20126 files processed.
# 14/20126 files processed.
# 15/20126 files processed.
# 16/20126 files processed.
# 17/20126 files processed.
# 18/20126 files processed.
# 19/20126 files processed.
# 20/20126 files processed.
# 21/20126 files processed.
# 22/20126 files processed.
# 23/20126 files processed.
# 24/20126 files processed.
# 25/20126 files processed.
# 26/20126 files processed.
# 27/20126 files processed.
# 28/20126 files processed.
# 29/20126 files processed.
# 30/20126 files processed.
# 31/20126 files processed.
# 32/20126 files processed.
# 33/20126 files processed.
# 34/20126 files processed.
# 35/20126 files processed.
# 36/20126 files processed.
# 37/20126 files processed.
# 38/20126 files processed.
# 39/20126 files processed.
# 40/20126 files processed.
# 41/20126 files processed.
# 42/20126 files processed.
# 43/20126 files processed.
# 44/20126 files processed.
# 45/20126 files processed.
# 46/20126 files processed.
# 47/20126 files processed.
# 48/20126 files processed.
# 49/20126 files processed.
# 50/20126 files processed.
# 51/20126 files processed.
# 52/20126 files processed.
# 53/20126 files processed.
# 54/20126 files processed.
# 55/20126 files processed.
# 56/20126 files processed.
# 57/20126 files processed.
# 58/20126 files processed.
# 59/20126 files processed.
# 60/20126 files processed.
# 61/20126 files processed.
# 62/20126 files processed.
# 63/20126 files processed.
# 64/20126 files processed.
# 65/20126 files processed.
# 66/20126 files processed.
# 67/20126 files processed.
# 68/20126 files processed.
# 69/20126 files processed.
# 70/20126 files processed.
# 71/20126 files processed.
# 72/20126 files processed.
# 73/20126 files processed.
# 74/20126 files processed.
# 75/20126 files processed.
# 76/20126 files processed.
# 77/20126 files processed.
# 78/20126 files processed.
# 79/20126 files processed.
# 80/20126 files processed.
# 81/20126 files processed.
# 82/20126 files processed.
# 83/20126 files processed.
# 84/20126 files processed.
# 85/20126 files processed.
# 86/20126 files processed.
# 87/20126 files processed.
# 88/20126 files processed.
# 89/20126 files processed.
# 90/20126 files processed.
# 91/20126 files processed.
# 92/20126 files processed.
# 93/20126 files processed.
# 94/20126 files processed.
# 95/20126 files processed.
# 96/20126 files processed.
# 97/20126 files processed.
# 98/20126 files processed.
# 99/20126 files processed.
# 100/20126 files processed.
# 101/20126 files processed.
# 102/20126 files processed.
# 103/20126 files processed.
# 104/20126 files processed.
# 105/20126 files processed.
# 106/20126 files processed.
# 107/20126 files processed.
# 108/20126 files processed.
# 109/20126 files processed.
# 110/20126 files processed.
# 111/20126 files processed.
# 112/20126 files processed.
# 113/20126 files processed.
# 114/20126 files processed.
# 115/20126 files processed.
# 116/20126 files processed.
# 117/20126 files processed.
# 118/20126 files processed.
# 119/20126 files processed.
# 120/20126 files processed.
# 121/20126 files processed.
# 122/20126 files processed.
# 123/20126 files processed.
# 124/20126 files processed.
# 125/20126 files processed.
# 126/20126 files processed.
# 127/20126 files processed.
# 128/20126 files processed.
# 129/20126 files processed.
# 130/20126 files processed.
# 131/20126 files processed.
# 132/20126 files processed.
# 133/20126 files processed.
# 134/20126 files processed.
# 135/20126 files processed.
# 136/20126 files processed.
# 137/20126 files processed.
# 138/20126 files processed.
# 139/20126 files processed.
# 140/20126 files processed.
# 141/20126 files processed.
# 142/20126 files processed.
# 143/20126 files processed.
# 144/20126 files processed.
# 145/20126 files processed.
# 146/20126 files processed.
# 147/20126 files processed.
# 148/20126 files processed.
# 149/20126 files processed.
# 150/20126 files processed.
# 151/20126 files processed.
# 152/20126 files processed.
# 153/20126 files processed.
# 154/20126 files processed.
# 155/20126 files processed.
# 156/20126 files processed.
# 157/20126 files processed.
# 158/20126 files processed.
# 159/20126 files processed.
# 160/20126 files processed.
# 161/20126 files processed.
# 162/20126 files processed.
# 163/20126 files processed.
# 164/20126 files processed.
# 165/20126 files processed.
# 166/20126 files processed.
# 167/20126 files processed.
# 168/20126 files processed.
# 169/20126 files processed.
# 170/20126 files processed.
# 171/20126 files processed.
# 172/20126 files processed.
# 173/20126 files processed.
# 174/20126 files processed.
# 175/20126 files processed.
# 176/20126 files processed.
# 177/20126 files processed.
# 178/20126 files processed.
# 179/20126 files processed.
# 180/20126 files processed.
# 181/20126 files processed.
# 182/20126 files processed.
# 183/20126 files processed.
# 184/20126 files processed.
# 185/20126 files processed.
# 186/20126 files processed.
# 187/20126 files processed.
# 188/20126 files processed.
# 189/20126 files processed.
# 190/20126 files processed.
# 191/20126 files processed.
# 192/20126 files processed.
# 193/20126 files processed.
# 194/20126 files processed.
# 195/20126 files processed.
# 196/20126 files processed.
# 197/20126 files processed.
# 198/20126 files processed.
# 199/20126 files processed.
# 200/20126 files processed.
# 201/20126 files processed.
# 202/20126 files processed.
# 203/20126 files processed.
# 204/20126 files processed.
# 205/20126 files processed.
# 206/20126 files processed.
# 207/20126 files processed.
# 208/20126 files processed.
# 209/20126 files processed.
# 210/20126 files processed.
# 211/20126 files processed.
# 212/20126 files processed.
# 213/20126 files processed.
# 214/20126 files processed.
# 215/20126 files processed.
# 216/20126 files processed.
# 217/20126 files processed.
# 218/20126 files processed.
# 219/20126 files processed.
# 220/20126 files processed.
# 221/20126 files processed.
# 222/20126 files processed.
# 223/20126 files processed.
# 224/20126 files processed.
# 225/20126 files processed.
# 226/20126 files processed.
# 227/20126 files processed.
# 228/20126 files processed.
# 229/20126 files processed.
# 230/20126 files processed.
# 231/20126 files processed.
# 232/20126 files processed.
# 233/20126 files processed.
# 234/20126 files processed.
# 235/20126 files processed.
# 236/20126 files processed.
# 237/20126 files processed.
# 238/20126 files processed.
# 239/20126 files processed.
# 240/20126 files processed.
# 241/20126 files processed.
# 242/20126 files processed.
# 243/20126 files processed.
# 244/20126 files processed.
# 245/20126 files processed.
# 246/20126 files processed.
# 247/20126 files processed.
# 248/20126 files processed.
# 249/20126 files processed.
# 250/20126 files processed.
# 251/20126 files processed.
# 252/20126 files processed.
# 253/20126 files processed.
# 254/20126 files processed.
# 255/20126 files processed.
# 256/20126 files processed.
# 257/20126 files processed.
# 258/20126 files processed.
# 259/20126 files processed.
# 260/20126 files processed.
# 261/20126 files processed.
# 262/20126 files processed.
# 263/20126 files processed.
# 264/20126 files processed.
# 265/20126 files processed.
# 266/20126 files processed.
# 267/20126 files processed.
# 268/20126 files processed.
# 269/20126 files processed.
# 270/20126 files processed.
# 271/20126 files processed.
# 272/20126 files processed.
# 273/20126 files processed.
# 274/20126 files processed.
# 275/20126 files processed.
# 276/20126 files processed.
# 277/20126 files processed.
# 278/20126 files processed.
# 279/20126 files processed.
# 280/20126 files processed.
# 281/20126 files processed.
# 282/20126 files processed.
# 283/20126 files processed.
# 284/20126 files processed.
# 285/20126 files processed.
# 286/20126 files processed.
# 287/20126 files processed.
# 288/20126 files processed.
# 289/20126 files processed.
# 290/20126 files processed.
# 291/20126 files processed.
# 292/20126 files processed.
# 293/20126 files processed.
# 294/20126 files processed.
# 295/20126 files processed.
# 296/20126 files processed.
# 297/20126 files processed.
# 298/20126 files processed.
# 299/20126 files processed.
# 300/20126 files processed.
# 301/20126 files processed.
# 302/20126 files processed.
# 303/20126 files processed.
# 304/20126 files processed.
# 305/20126 files processed.
# 306/20126 files processed.
# 307/20126 files processed.
# 308/20126 files processed.
# 309/20126 files processed.
# 310/20126 files processed.
# 311/20126 files processed.
# 312/20126 files processed.
# 313/20126 files processed.
# 314/20126 files processed.
# 315/20126 files processed.
# 316/20126 files processed.
# 317/20126 files processed.
# 318/20126 files processed.
# 319/20126 files processed.
# 320/20126 files processed.
# 321/20126 files processed.
# 322/20126 files processed.
# 323/20126 files processed.
# 324/20126 files processed.
# 325/20126 files processed.
# 326/20126 files processed.
# 327/20126 files processed.
# 328/20126 files processed.
# 329/20126 files processed.
# 330/20126 files processed.
# 331/20126 files processed.
# 332/20126 files processed.
# 333/20126 files processed.
# 334/20126 files processed.
# 335/20126 files processed.
# 336/20126 files processed.
# 337/20126 files processed.
# 338/20126 files processed.
# 339/20126 files processed.
# 340/20126 files processed.
# 341/20126 files processed.
# 342/20126 files processed.
# 343/20126 files processed.
# 344/20126 files processed.
# 345/20126 files processed.
# 346/20126 files processed.
# 347/20126 files processed.
# 348/20126 files processed.
# 349/20126 files processed.
# 350/20126 files processed.
# 351/20126 files processed.
# 352/20126 files processed.
# 353/20126 files processed.
# 354/20126 files processed.
# 355/20126 files processed.
# 356/20126 files processed.
# 357/20126 files processed.
# 358/20126 files processed.
# 359/20126 files processed.
# 360/20126 files processed.
# 361/20126 files processed.
# 362/20126 files processed.
# 363/20126 files processed.
# 364/20126 files processed.
# 365/20126 files processed.
# 366/20126 files processed.
# 367/20126 files processed.
# 368/20126 files processed.
# 369/20126 files processed.
# 370/20126 files processed.
# 371/20126 files processed.
# 372/20126 files processed.
# 373/20126 files processed.
# 374/20126 files processed.
# 375/20126 files processed.
# 376/20126 files processed.
# 377/20126 files processed.
# 378/20126 files processed.
# 379/20126 files processed.
# 380/20126 files processed.
# 381/20126 files processed.
# 382/20126 files processed.
# 383/20126 files processed.
# 384/20126 files processed.
# 385/20126 files processed.
# 386/20126 files processed.
# 387/20126 files processed.
# 388/20126 files processed.
# 389/20126 files processed.
# 390/20126 files processed.
# 391/20126 files processed.
# 392/20126 files processed.
# 393/20126 files processed.
# 394/20126 files processed.
# 395/20126 files processed.
# 396/20126 files processed.
# 397/20126 files processed.
# 398/20126 files processed.
# 399/20126 files processed.
# 400/20126 files processed.
# 401/20126 files processed.
# 402/20126 files processed.
# 403/20126 files processed.
# 404/20126 files processed.
# 405/20126 files processed.
# 406/20126 files processed.
# 407/20126 files processed.
# 408/20126 files processed.
# 409/20126 files processed.
# 410/20126 files processed.
# 411/20126 files processed.
# 412/20126 files processed.
# 413/20126 files processed.
# 414/20126 files processed.
# 415/20126 files processed.
# 416/20126 files processed.
# 417/20126 files processed.
# 418/20126 files processed.
# 419/20126 files processed.
# 420/20126 files processed.
# 421/20126 files processed.
# 422/20126 files processed.
# 423/20126 files processed.
# 424/20126 files processed.
# 425/20126 files processed.
# 426/20126 files processed.
# 427/20126 files processed.
# 428/20126 files processed.
# 429/20126 files processed.
# 430/20126 files processed.
# 431/20126 files processed.
# 432/20126 files processed.
# 433/20126 files processed.
# 434/20126 files processed.
# 435/20126 files processed.
# 436/20126 files processed.
# 437/20126 files processed.
# 438/20126 files processed.
# 439/20126 files processed.
# 440/20126 files processed.
# 441/20126 files processed.
# 442/20126 files processed.
# 443/20126 files processed.
# 444/20126 files processed.
# 445/20126 files processed.
# 446/20126 files processed.
# 447/20126 files processed.
# 448/20126 files processed.
# 449/20126 files processed.
# 450/20126 files processed.
# 451/20126 files processed.
# 452/20126 files processed.
# 453/20126 files processed.
# 454/20126 files processed.
# 455/20126 files processed.
# 456/20126 files processed.
# 457/20126 files processed.
# 458/20126 files processed.
# 459/20126 files processed.
# 460/20126 files processed.
# 461/20126 files processed.
# 462/20126 files processed.
# 463/20126 files processed.
# 464/20126 files processed.
# 465/20126 files processed.
# 466/20126 files processed.
# 467/20126 files processed.
# 468/20126 files processed.
# 469/20126 files processed.
# 470/20126 files processed.
# 471/20126 files processed.
# 472/20126 files processed.
# 473/20126 files processed.
# 474/20126 files processed.
# 475/20126 files processed.
# 476/20126 files processed.
# 477/20126 files processed.
# 478/20126 files processed.
# 479/20126 files processed.
# 480/20126 files processed.
# 481/20126 files processed.
# 482/20126 files processed.
# 483/20126 files processed.
# 484/20126 files processed.
# 485/20126 files processed.
# 486/20126 files processed.
# 487/20126 files processed.
# 488/20126 files processed.
# 489/20126 files processed.
# 490/20126 files processed.
# 491/20126 files processed.
# 492/20126 files processed.
# 493/20126 files processed.
# 494/20126 files processed.
# 495/20126 files processed.
# 496/20126 files processed.
# 497/20126 files processed.
# 498/20126 files processed.
# 499/20126 files processed.
# 500/20126 files processed.
# 501/20126 files processed.
# 502/20126 files processed.
# 503/20126 files processed.
# 504/20126 files processed.
# 505/20126 files processed.
# 506/20126 files processed.
# 507/20126 files processed.
# 508/20126 files processed.
# 509/20126 files processed.
# 510/20126 files processed.
# 511/20126 files processed.
# 512/20126 files processed.
# 513/20126 files processed.
# 514/20126 files processed.
# 515/20126 files processed.
# 516/20126 files processed.
# 517/20126 files processed.
# 518/20126 files processed.
# 519/20126 files processed.
# 520/20126 files processed.
# 521/20126 files processed.
# 522/20126 files processed.
# 523/20126 files processed.
# 524/20126 files processed.
# 525/20126 files processed.
# 526/20126 files processed.
# 527/20126 files processed.
# 528/20126 files processed.
# 529/20126 files processed.
# 530/20126 files processed.
# 531/20126 files processed.
# 532/20126 files processed.
# 533/20126 files processed.
# 534/20126 files processed.
# 535/20126 files processed.
# 536/20126 files processed.
# 537/20126 files processed.
# 538/20126 files processed.
# 539/20126 files processed.
# 540/20126 files processed.
# 541/20126 files processed.
# 542/20126 files processed.
# 543/20126 files processed.
# 544/20126 files processed.
# 545/20126 files processed.
# 546/20126 files processed.
# 547/20126 files processed.
# 548/20126 files processed.
# 549/20126 files processed.
# 550/20126 files processed.
# 551/20126 files processed.
# 552/20126 files processed.
# 553/20126 files processed.
# 554/20126 files processed.
# 555/20126 files processed.
# 556/20126 files processed.
# 557/20126 files processed.
# 558/20126 files processed.
# 559/20126 files processed.
# 560/20126 files processed.
# 561/20126 files processed.
# 562/20126 files processed.
# 563/20126 files processed.
# 564/20126 files processed.
# 565/20126 files processed.
# 566/20126 files processed.
# 567/20126 files processed.
# 568/20126 files processed.
# 569/20126 files processed.
# 570/20126 files processed.
# 571/20126 files processed.
# 572/20126 files processed.
# 573/20126 files processed.
# 574/20126 files processed.
# 575/20126 files processed.
# 576/20126 files processed.
# 577/20126 files processed.
# 578/20126 files processed.
# 579/20126 files processed.
# 580/20126 files processed.
# 581/20126 files processed.
# 582/20126 files processed.
# 583/20126 files processed.
# 584/20126 files processed.
# 585/20126 files processed.
# 586/20126 files processed.
# 587/20126 files processed.
# 588/20126 files processed.
# 589/20126 files processed.
# 590/20126 files processed.
# 591/20126 files processed.
# 592/20126 files processed.
# 593/20126 files processed.
# 594/20126 files processed.
# 595/20126 files processed.
# 596/20126 files processed.
# 597/20126 files processed.
# 598/20126 files processed.
# 599/20126 files processed.
# 600/20126 files processed.
# 601/20126 files processed.
# 602/20126 files processed.
# 603/20126 files processed.
# 604/20126 files processed.
# 605/20126 files processed.
# 606/20126 files processed.
# 607/20126 files processed.
# 608/20126 files processed.
# 609/20126 files processed.
# 610/20126 files processed.
# 611/20126 files processed.
# 612/20126 files processed.
# 613/20126 files processed.
# 614/20126 files processed.
# 615/20126 files processed.
# 616/20126 files processed.
# 617/20126 files processed.
# 618/20126 files processed.
# 619/20126 files processed.
# 620/20126 files processed.
# 621/20126 files processed.
# 622/20126 files processed.
# 623/20126 files processed.
# 624/20126 files processed.
# 625/20126 files processed.
# 626/20126 files processed.
# 627/20126 files processed.
# 628/20126 files processed.
# 629/20126 files processed.
# 630/20126 files processed.
# 631/20126 files processed.
# 632/20126 files processed.
# 633/20126 files processed.
# 634/20126 files processed.
# 635/20126 files processed.
# 636/20126 files processed.
# 637/20126 files processed.
# 638/20126 files processed.
# 639/20126 files processed.
# 640/20126 files processed.
# 641/20126 files processed.
# 642/20126 files processed.
# 643/20126 files processed.
# 644/20126 files processed.
# 645/20126 files processed.
# 646/20126 files processed.
# 647/20126 files processed.
# 648/20126 files processed.
# 649/20126 files processed.
# 650/20126 files processed.
# 651/20126 files processed.
# 652/20126 files processed.
# 653/20126 files processed.
# 654/20126 files processed.
# 655/20126 files processed.
# 656/20126 files processed.
# 657/20126 files processed.
# 658/20126 files processed.
# 659/20126 files processed.
# 660/20126 files processed.
# 661/20126 files processed.
# 662/20126 files processed.
# 663/20126 files processed.
# 664/20126 files processed.
# 665/20126 files processed.
# 666/20126 files processed.
# 667/20126 files processed.
# 668/20126 files processed.
# 669/20126 files processed.
# 670/20126 files processed.
# 671/20126 files processed.
# 672/20126 files processed.
# 673/20126 files processed.
# 674/20126 files processed.
# 675/20126 files processed.
# 676/20126 files processed.
# 677/20126 files processed.
# 678/20126 files processed.
# 679/20126 files processed.
# 680/20126 files processed.
# 681/20126 files processed.
# 682/20126 files processed.
# 683/20126 files processed.
# 684/20126 files processed.
# 685/20126 files processed.
# 686/20126 files processed.
# 687/20126 files processed.
# 688/20126 files processed.
# 689/20126 files processed.
# 690/20126 files processed.
# 691/20126 files processed.
# 692/20126 files processed.
# 693/20126 files processed.
# 694/20126 files processed.
# 695/20126 files processed.
# 696/20126 files processed.
# 697/20126 files processed.
# 698/20126 files processed.
# 699/20126 files processed.
# 700/20126 files processed.
# 701/20126 files processed.
# 702/20126 files processed.
# 703/20126 files processed.
# 704/20126 files processed.
# 705/20126 files processed.
# 706/20126 files processed.
# 707/20126 files processed.
# 708/20126 files processed.
# 709/20126 files processed.
# 710/20126 files processed.
# 711/20126 files processed.
# 712/20126 files processed.
# 713/20126 files processed.
# 714/20126 files processed.
# 715/20126 files processed.
# 716/20126 files processed.
# 717/20126 files processed.
# 718/20126 files processed.
# 719/20126 files processed.
# 720/20126 files processed.
# 721/20126 files processed.
# 722/20126 files processed.
# 723/20126 files processed.
# 724/20126 files processed.
# 725/20126 files processed.
# 726/20126 files processed.
# 727/20126 files processed.
# 728/20126 files processed.
# 729/20126 files processed.
# 730/20126 files processed.
# 731/20126 files processed.
# 732/20126 files processed.
# 733/20126 files processed.
# 734/20126 files processed.
# 735/20126 files processed.
# 736/20126 files processed.
# 737/20126 files processed.
# 738/20126 files processed.
# 739/20126 files processed.
# 740/20126 files processed.
# 741/20126 files processed.
# 742/20126 files processed.
# 743/20126 files processed.
# 744/20126 files processed.
# 745/20126 files processed.
# 746/20126 files processed.
# 747/20126 files processed.
# 748/20126 files processed.
# 749/20126 files processed.
# 750/20126 files processed.
# 751/20126 files processed.
# 752/20126 files processed.
# 753/20126 files processed.
# 754/20126 files processed.
# 755/20126 files processed.
# 756/20126 files processed.
# 757/20126 files processed.
# 758/20126 files processed.
# 759/20126 files processed.
# 760/20126 files processed.
# 761/20126 files processed.
# 762/20126 files processed.
# 763/20126 files processed.
# 764/20126 files processed.
# 765/20126 files processed.
# 766/20126 files processed.
# 767/20126 files processed.
# 768/20126 files processed.
# 769/20126 files processed.
# 770/20126 files processed.
# 771/20126 files processed.
# 772/20126 files processed.
# 773/20126 files processed.
# 774/20126 files processed.
# 775/20126 files processed.
# 776/20126 files processed.
# 777/20126 files processed.
# 778/20126 files processed.
# 779/20126 files processed.
# 780/20126 files processed.
# 781/20126 files processed.
# 782/20126 files processed.
# 783/20126 files processed.
# 784/20126 files processed.
# 785/20126 files processed.
# 786/20126 files processed.
# 787/20126 files processed.
# 788/20126 files processed.
# 789/20126 files processed.
# 790/20126 files processed.
# 791/20126 files processed.
# 792/20126 files processed.
# 793/20126 files processed.
# 794/20126 files processed.
# 795/20126 files processed.
# 796/20126 files processed.
# 797/20126 files processed.
# 798/20126 files processed.
# 799/20126 files processed.
# 800/20126 files processed.
# 801/20126 files processed.
# 802/20126 files processed.
# 803/20126 files processed.
# 804/20126 files processed.
# 805/20126 files processed.
# 806/20126 files processed.
# 807/20126 files processed.
# 808/20126 files processed.
# 809/20126 files processed.
# 810/20126 files processed.
# 811/20126 files processed.
# 812/20126 files processed.
# 813/20126 files processed.
# 814/20126 files processed.
# 815/20126 files processed.
# 816/20126 files processed.
# 817/20126 files processed.
# 818/20126 files processed.
# 819/20126 files processed.
# 820/20126 files processed.
# 821/20126 files processed.
# 822/20126 files processed.
# 823/20126 files processed.
# 824/20126 files processed.
# 825/20126 files processed.
# 826/20126 files processed.
# 827/20126 files processed.
# 828/20126 files processed.
# 829/20126 files processed.
# 830/20126 files processed.
# 831/20126 files processed.
# 832/20126 files processed.
# 833/20126 files processed.
# 834/20126 files processed.
# 835/20126 files processed.
# 836/20126 files processed.
# 837/20126 files processed.
# 838/20126 files processed.
# 839/20126 files processed.
# 840/20126 files processed.
# 841/20126 files processed.
# 842/20126 files processed.
# 843/20126 files processed.
# 844/20126 files processed.
# 845/20126 files processed.
# 846/20126 files processed.
# 847/20126 files processed.
# 848/20126 files processed.
# 849/20126 files processed.
# 850/20126 files processed.
# 851/20126 files processed.
# 852/20126 files processed.
# 853/20126 files processed.
# 854/20126 files processed.
# 855/20126 files processed.
# 856/20126 files processed.
# 857/20126 files processed.
# 858/20126 files processed.
# 859/20126 files processed.
# 860/20126 files processed.
# 861/20126 files processed.
# 862/20126 files processed.
# 863/20126 files processed.
# 864/20126 files processed.
# 865/20126 files processed.
# 866/20126 files processed.
# 867/20126 files processed.
# 868/20126 files processed.
# 869/20126 files processed.
# 870/20126 files processed.
# 871/20126 files processed.
# 872/20126 files processed.
# 873/20126 files processed.
# 874/20126 files processed.
# 875/20126 files processed.
# 876/20126 files processed.
# 877/20126 files processed.
# 878/20126 files processed.
# 879/20126 files processed.
# 880/20126 files processed.
# 881/20126 files processed.
# 882/20126 files processed.
# 883/20126 files processed.
# 884/20126 files processed.
# 885/20126 files processed.
# 886/20126 files processed.
# 887/20126 files processed.
# 888/20126 files processed.
# 889/20126 files processed.
# 890/20126 files processed.
# 891/20126 files processed.
# 892/20126 files processed.
# 893/20126 files processed.
# 894/20126 files processed.
# 895/20126 files processed.
# 896/20126 files processed.
# 897/20126 files processed.
# 898/20126 files processed.
# 899/20126 files processed.
# 900/20126 files processed.
# 901/20126 files processed.
# 902/20126 files processed.
# 903/20126 files processed.
# 904/20126 files processed.
# 905/20126 files processed.
# 906/20126 files processed.
# 907/20126 files processed.
# 908/20126 files processed.
# 909/20126 files processed.
# 910/20126 files processed.
# 911/20126 files processed.
# 912/20126 files processed.
# 913/20126 files processed.
# 914/20126 files processed.
# 915/20126 files processed.
# 916/20126 files processed.
# 917/20126 files processed.
# 918/20126 files processed.
# 919/20126 files processed.
# 920/20126 files processed.
# 921/20126 files processed.
# 922/20126 files processed.
# 923/20126 files processed.
# 924/20126 files processed.
# 925/20126 files processed.
# 926/20126 files processed.
# 927/20126 files processed.
# 928/20126 files processed.
# 929/20126 files processed.
# 930/20126 files processed.
# 931/20126 files processed.
# 932/20126 files processed.
# 933/20126 files processed.
# 934/20126 files processed.
# 935/20126 files processed.
# 936/20126 files processed.
# 937/20126 files processed.
# 938/20126 files processed.
# 939/20126 files processed.
# 940/20126 files processed.
# 941/20126 files processed.
# 942/20126 files processed.
# 943/20126 files processed.
# 944/20126 files processed.
# 945/20126 files processed.
# 946/20126 files processed.
# 947/20126 files processed.
# 948/20126 files processed.
# 949/20126 files processed.
# 950/20126 files processed.
# 951/20126 files processed.
# 952/20126 files processed.
# 953/20126 files processed.
# 954/20126 files processed.
# 955/20126 files processed.
# 956/20126 files processed.
# 957/20126 files processed.
# 958/20126 files processed.
# 959/20126 files processed.
# 960/20126 files processed.
# 961/20126 files processed.
# 962/20126 files processed.
# 963/20126 files processed.
# 964/20126 files processed.
# 965/20126 files processed.
# 966/20126 files processed.
# 967/20126 files processed.
# 968/20126 files processed.
# 969/20126 files processed.
# 970/20126 files processed.
# 971/20126 files processed.
# 972/20126 files processed.
# 973/20126 files processed.
# 974/20126 files processed.
# 975/20126 files processed.
# 976/20126 files processed.
# 977/20126 files processed.
# 978/20126 files processed.
# 979/20126 files processed.
# 980/20126 files processed.
# 981/20126 files processed.
# 982/20126 files processed.
# 983/20126 files processed.
# 984/20126 files processed.
# 985/20126 files processed.
# 986/20126 files processed.
# 987/20126 files processed.
# 988/20126 files processed.
# 989/20126 files processed.
# 990/20126 files processed.
# 991/20126 files processed.
# 992/20126 files processed.
# 993/20126 files processed.
# 994/20126 files processed.
# 995/20126 files processed.
# 996/20126 files processed.
# 997/20126 files processed.
# 998/20126 files processed.
# 999/20126 files processed.
# 1000/20126 files processed.
# 1001/20126 files processed.
# 1002/20126 files processed.
# 1003/20126 files processed.
# 1004/20126 files processed.
# 1005/20126 files processed.
# 1006/20126 files processed.
# 1007/20126 files processed.
# 1008/20126 files processed.
# 1009/20126 files processed.
# 1010/20126 files processed.
# 1011/20126 files processed.
# 1012/20126 files processed.
# 1013/20126 files processed.
# 1014/20126 files processed.
# 1015/20126 files processed.
# 1016/20126 files processed.
# 1017/20126 files processed.
# 1018/20126 files processed.
# 1019/20126 files processed.
# 1020/20126 files processed.
# 1021/20126 files processed.
# 1022/20126 files processed.
# 1023/20126 files processed.
# 1024/20126 files processed.
# 1025/20126 files processed.
# 1026/20126 files processed.
# 1027/20126 files processed.
# 1028/20126 files processed.
# 1029/20126 files processed.
# 1030/20126 files processed.
# 1031/20126 files processed.
# 1032/20126 files processed.
# 1033/20126 files processed.
# 1034/20126 files processed.
# 1035/20126 files processed.
# 1036/20126 files processed.
# 1037/20126 files processed.
# 1038/20126 files processed.
# 1039/20126 files processed.
# 1040/20126 files processed.
# 1041/20126 files processed.
# 1042/20126 files processed.
# 1043/20126 files processed.
# 1044/20126 files processed.
# 1045/20126 files processed.
# 1046/20126 files processed.
# 1047/20126 files processed.
# 1048/20126 files processed.
# 1049/20126 files processed.
# 1050/20126 files processed.
# 1051/20126 files processed.
# 1052/20126 files processed.
# 1053/20126 files processed.
# 1054/20126 files processed.
# 1055/20126 files processed.
# 1056/20126 files processed.
# 1057/20126 files processed.
# 1058/20126 files processed.
# 1059/20126 files processed.
# 1060/20126 files processed.
# 1061/20126 files processed.
# 1062/20126 files processed.
# 1063/20126 files processed.
# 1064/20126 files processed.
# 1065/20126 files processed.
# 1066/20126 files processed.
# 1067/20126 files processed.
# 1068/20126 files processed.
# 1069/20126 files processed.
# 1070/20126 files processed.
# 1071/20126 files processed.
# 1072/20126 files processed.
# 1073/20126 files processed.
# 1074/20126 files processed.
# 1075/20126 files processed.
# 1076/20126 files processed.
# 1077/20126 files processed.
# 1078/20126 files processed.
# 1079/20126 files processed.
# 1080/20126 files processed.
# 1081/20126 files processed.
# 1082/20126 files processed.
# 1083/20126 files processed.
# 1084/20126 files processed.
# 1085/20126 files processed.
# 1086/20126 files processed.
# 1087/20126 files processed.
# 1088/20126 files processed.
# 1089/20126 files processed.
# 1090/20126 files processed.
# 1091/20126 files processed.
# 1092/20126 files processed.
# 1093/20126 files processed.
# 1094/20126 files processed.
# 1095/20126 files processed.
# 1096/20126 files processed.
# 1097/20126 files processed.
# 1098/20126 files processed.
# 1099/20126 files processed.
# 1100/20126 files processed.
# 1101/20126 files processed.
# 1102/20126 files processed.
# 1103/20126 files processed.
# 1104/20126 files processed.
# 1105/20126 files processed.
# 1106/20126 files processed.
# 1107/20126 files processed.
# 1108/20126 files processed.
# 1109/20126 files processed.
# 1110/20126 files processed.
# 1111/20126 files processed.
# 1112/20126 files processed.
# 1113/20126 files processed.
# 1114/20126 files processed.
# 1115/20126 files processed.
# 1116/20126 files processed.
# 1117/20126 files processed.
# 1118/20126 files processed.
# 1119/20126 files processed.
# 1120/20126 files processed.
# 1121/20126 files processed.
# 1122/20126 files processed.
# 1123/20126 files processed.
# 1124/20126 files processed.
# 1125/20126 files processed.
# 1126/20126 files processed.
# 1127/20126 files processed.
# 1128/20126 files processed.
# 1129/20126 files processed.
# 1130/20126 files processed.
# 1131/20126 files processed.
# 1132/20126 files processed.
# 1133/20126 files processed.
# 1134/20126 files processed.
# 1135/20126 files processed.
# 1136/20126 files processed.
# 1137/20126 files processed.
# 1138/20126 files processed.
# 1139/20126 files processed.
# 1140/20126 files processed.
# 1141/20126 files processed.
# 1142/20126 files processed.
# 1143/20126 files processed.
# 1144/20126 files processed.
# 1145/20126 files processed.
# 1146/20126 files processed.
# 1147/20126 files processed.
# 1148/20126 files processed.
# 1149/20126 files processed.
# 1150/20126 files processed.
# 1151/20126 files processed.
# 1152/20126 files processed.
# 1153/20126 files processed.
# 1154/20126 files processed.
# 1155/20126 files processed.
# 1156/20126 files processed.
# 1157/20126 files processed.
# 1158/20126 files processed.
# 1159/20126 files processed.
# 1160/20126 files processed.
# 1161/20126 files processed.
# 1162/20126 files processed.
# 1163/20126 files processed.
# 1164/20126 files processed.
# 1165/20126 files processed.
# 1166/20126 files processed.
# 1167/20126 files processed.
# 1168/20126 files processed.
# 1169/20126 files processed.
# 1170/20126 files processed.
# 1171/20126 files processed.
# 1172/20126 files processed.
# 1173/20126 files processed.
# 1174/20126 files processed.
# 1175/20126 files processed.
# 1176/20126 files processed.
# 1177/20126 files processed.
# 1178/20126 files processed.
# 1179/20126 files processed.
# 1180/20126 files processed.
# 1181/20126 files processed.
# 1182/20126 files processed.
# 1183/20126 files processed.
# 1184/20126 files processed.
# 1185/20126 files processed.
# 1186/20126 files processed.
# 1187/20126 files processed.
# 1188/20126 files processed.
# 1189/20126 files processed.
# 1190/20126 files processed.
# 1191/20126 files processed.
# 1192/20126 files processed.
# 1193/20126 files processed.
# 1194/20126 files processed.
# 1195/20126 files processed.
# 1196/20126 files processed.
# 1197/20126 files processed.
# 1198/20126 files processed.
# 1199/20126 files processed.
# 1200/20126 files processed.
# 1201/20126 files processed.
# 1202/20126 files processed.
# 1203/20126 files processed.
# 1204/20126 files processed.
# 1205/20126 files processed.
# 1206/20126 files processed.
# 1207/20126 files processed.
# 1208/20126 files processed.
# 1209/20126 files processed.
# 1210/20126 files processed.
# 1211/20126 files processed.
# 1212/20126 files processed.
# 1213/20126 files processed.
# 1214/20126 files processed.
# 1215/20126 files processed.
# 1216/20126 files processed.
# 1217/20126 files processed.
# 1218/20126 files processed.
# 1219/20126 files processed.
# 1220/20126 files processed.
# 1221/20126 files processed.
# 1222/20126 files processed.
# 1223/20126 files processed.
# 1224/20126 files processed.
# 1225/20126 files processed.
# 1226/20126 files processed.
# 1227/20126 files processed.
# 1228/20126 files processed.
# 1229/20126 files processed.
# 1230/20126 files processed.
# 1231/20126 files processed.
# 1232/20126 files processed.
# 1233/20126 files processed.
# 1234/20126 files processed.
# 1235/20126 files processed.
# 1236/20126 files processed.
# 1237/20126 files processed.
# 1238/20126 files processed.
# 1239/20126 files processed.
# 1240/20126 files processed.
# 1241/20126 files processed.
# 1242/20126 files processed.
# 1243/20126 files processed.
# 1244/20126 files processed.
# 1245/20126 files processed.
# 1246/20126 files processed.
# 1247/20126 files processed.
# 1248/20126 files processed.
# 1249/20126 files processed.
# 1250/20126 files processed.
# 1251/20126 files processed.
# 1252/20126 files processed.
# 1253/20126 files processed.
# 1254/20126 files processed.
# 1255/20126 files processed.
# 1256/20126 files processed.
# 1257/20126 files processed.
# 1258/20126 files processed.
# 1259/20126 files processed.
# 1260/20126 files processed.
# 1261/20126 files processed.
# 1262/20126 files processed.
# 1263/20126 files processed.
# 1264/20126 files processed.
# 1265/20126 files processed.
# 1266/20126 files processed.
# 1267/20126 files processed.
# 1268/20126 files processed.
# 1269/20126 files processed.
# 1270/20126 files processed.
# 1271/20126 files processed.
# 1272/20126 files processed.
# 1273/20126 files processed.
# 1274/20126 files processed.
# 1275/20126 files processed.
# 1276/20126 files processed.
# 1277/20126 files processed.
# 1278/20126 files processed.
# 1279/20126 files processed.
# 1280/20126 files processed.
# 1281/20126 files processed.
# 1282/20126 files processed.
# 1283/20126 files processed.
# 1284/20126 files processed.
# 1285/20126 files processed.
# 1286/20126 files processed.
# 1287/20126 files processed.
# 1288/20126 files processed.
# 1289/20126 files processed.
# 1290/20126 files processed.
# 1291/20126 files processed.
# 1292/20126 files processed.
# 1293/20126 files processed.
# 1294/20126 files processed.
# 1295/20126 files processed.
# 1296/20126 files processed.
# 1297/20126 files processed.
# 1298/20126 files processed.
# 1299/20126 files processed.
# 1300/20126 files processed.
# 1301/20126 files processed.
# 1302/20126 files processed.
# 1303/20126 files processed.
# 1304/20126 files processed.
# 1305/20126 files processed.
# 1306/20126 files processed.
# 1307/20126 files processed.
# 1308/20126 files processed.
# 1309/20126 files processed.
# 1310/20126 files processed.
# 1311/20126 files processed.
# 1312/20126 files processed.
# 1313/20126 files processed.
# 1314/20126 files processed.
# 1315/20126 files processed.
# 1316/20126 files processed.
# 1317/20126 files processed.
# 1318/20126 files processed.
# 1319/20126 files processed.
# 1320/20126 files processed.
# 1321/20126 files processed.
# 1322/20126 files processed.
# 1323/20126 files processed.
# 1324/20126 files processed.
# 1325/20126 files processed.
# 1326/20126 files processed.
# 1327/20126 files processed.
# 1328/20126 files processed.
# 1329/20126 files processed.
# 1330/20126 files processed.
# 1331/20126 files processed.
# 1332/20126 files processed.
# 1333/20126 files processed.
# 1334/20126 files processed.
# 1335/20126 files processed.
# 1336/20126 files processed.
# 1337/20126 files processed.
# 1338/20126 files processed.
# 1339/20126 files processed.
# 1340/20126 files processed.
# 1341/20126 files processed.
# 1342/20126 files processed.
# 1343/20126 files processed.
# 1344/20126 files processed.
# 1345/20126 files processed.
# 1346/20126 files processed.
# 1347/20126 files processed.
# 1348/20126 files processed.
# 1349/20126 files processed.
# 1350/20126 files processed.
# 1351/20126 files processed.
# 1352/20126 files processed.
# 1353/20126 files processed.
# 1354/20126 files processed.
# 1355/20126 files processed.
# 1356/20126 files processed.
# 1357/20126 files processed.
# 1358/20126 files processed.
# 1359/20126 files processed.
# 1360/20126 files processed.
# 1361/20126 files processed.
# 1362/20126 files processed.
# 1363/20126 files processed.
# 1364/20126 files processed.
# 1365/20126 files processed.
# 1366/20126 files processed.
# 1367/20126 files processed.
# 1368/20126 files processed.
# 1369/20126 files processed.
# 1370/20126 files processed.
# 1371/20126 files processed.
# 1372/20126 files processed.
# 1373/20126 files processed.
# 1374/20126 files processed.
# 1375/20126 files processed.
# 1376/20126 files processed.
# 1377/20126 files processed.
# 1378/20126 files processed.
# 1379/20126 files processed.
# 1380/20126 files processed.
# 1381/20126 files processed.
# 1382/20126 files processed.
# 1383/20126 files processed.
# 1384/20126 files processed.
# 1385/20126 files processed.
# 1386/20126 files processed.
# 1387/20126 files processed.
# 1388/20126 files processed.
# 1389/20126 files processed.
# 1390/20126 files processed.
# 1391/20126 files processed.
# 1392/20126 files processed.
# 1393/20126 files processed.
# 1394/20126 files processed.
# 1395/20126 files processed.
# 1396/20126 files processed.
# 1397/20126 files processed.
# 1398/20126 files processed.
# 1399/20126 files processed.
# 1400/20126 files processed.
# 1401/20126 files processed.
# 1402/20126 files processed.
# 1403/20126 files processed.
# 1404/20126 files processed.
# 1405/20126 files processed.
# 1406/20126 files processed.
# 1407/20126 files processed.
# 1408/20126 files processed.
# 1409/20126 files processed.
# 1410/20126 files processed.
# 1411/20126 files processed.
# 1412/20126 files processed.
# 1413/20126 files processed.
# 1414/20126 files processed.
# 1415/20126 files processed.
# 1416/20126 files processed.
# 1417/20126 files processed.
# 1418/20126 files processed.
# 1419/20126 files processed.
# 1420/20126 files processed.
# 1421/20126 files processed.
# 1422/20126 files processed.
# 1423/20126 files processed.
# 1424/20126 files processed.
# 1425/20126 files processed.
# 1426/20126 files processed.
# 1427/20126 files processed.
# 1428/20126 files processed.
# 1429/20126 files processed.
# 1430/20126 files processed.
# 1431/20126 files processed.
# 1432/20126 files processed.
# 1433/20126 files processed.
# 1434/20126 files processed.
# 1435/20126 files processed.
# 1436/20126 files processed.
# 1437/20126 files processed.
# 1438/20126 files processed.
# 1439/20126 files processed.
# 1440/20126 files processed.
# 1441/20126 files processed.
# 1442/20126 files processed.
# 1443/20126 files processed.
# 1444/20126 files processed.
# 1445/20126 files processed.
# 1446/20126 files processed.
# 1447/20126 files processed.
# 1448/20126 files processed.
# 1449/20126 files processed.
# 1450/20126 files processed.
# 1451/20126 files processed.
# 1452/20126 files processed.
# 1453/20126 files processed.
# 1454/20126 files processed.
# 1455/20126 files processed.
# 1456/20126 files processed.
# 1457/20126 files processed.
# 1458/20126 files processed.
# 1459/20126 files processed.
# 1460/20126 files processed.
# 1461/20126 files processed.
# 1462/20126 files processed.
# 1463/20126 files processed.
# 1464/20126 files processed.
# 1465/20126 files processed.
# 1466/20126 files processed.
# 1467/20126 files processed.
# 1468/20126 files processed.
# 1469/20126 files processed.
# 1470/20126 files processed.
# 1471/20126 files processed.
# 1472/20126 files processed.
# 1473/20126 files processed.
# 1474/20126 files processed.
# 1475/20126 files processed.
# 1476/20126 files processed.
# 1477/20126 files processed.
# 1478/20126 files processed.
# 1479/20126 files processed.
# 1480/20126 files processed.
# 1481/20126 files processed.
# 1482/20126 files processed.
# 1483/20126 files processed.
# 1484/20126 files processed.
# 1485/20126 files processed.
# 1486/20126 files processed.
# 1487/20126 files processed.
# 1488/20126 files processed.
# 1489/20126 files processed.
# 1490/20126 files processed.
# 1491/20126 files processed.
# 1492/20126 files processed.
# 1493/20126 files processed.
# 1494/20126 files processed.
# 1495/20126 files processed.
# 1496/20126 files processed.
# 1497/20126 files processed.
# 1498/20126 files processed.
# 1499/20126 files processed.
# 1500/20126 files processed.
# 1501/20126 files processed.
# 1502/20126 files processed.
# 1503/20126 files processed.
# 1504/20126 files processed.
# 1505/20126 files processed.
# 1506/20126 files processed.
# 1507/20126 files processed.
# 1508/20126 files processed.
# 1509/20126 files processed.
# 1510/20126 files processed.
# 1511/20126 files processed.
# 1512/20126 files processed.
# 1513/20126 files processed.
# 1514/20126 files processed.
# 1515/20126 files processed.
# 1516/20126 files processed.
# 1517/20126 files processed.
# 1518/20126 files processed.
# 1519/20126 files processed.
# 1520/20126 files processed.
# 1521/20126 files processed.
# 1522/20126 files processed.
# 1523/20126 files processed.
# 1524/20126 files processed.
# 1525/20126 files processed.
# 1526/20126 files processed.
# 1527/20126 files processed.
# 1528/20126 files processed.
# 1529/20126 files processed.
# 1530/20126 files processed.
# 1531/20126 files processed.
# 1532/20126 files processed.
# 1533/20126 files processed.
# 1534/20126 files processed.
# 1535/20126 files processed.
# 1536/20126 files processed.
# 1537/20126 files processed.
# 1538/20126 files processed.
# 1539/20126 files processed.
# 1540/20126 files processed.
# 1541/20126 files processed.
# 1542/20126 files processed.
# 1543/20126 files processed.
# 1544/20126 files processed.
# 1545/20126 files processed.
# 1546/20126 files processed.
# 1547/20126 files processed.
# 1548/20126 files processed.
# 1549/20126 files processed.
# 1550/20126 files processed.
# 1551/20126 files processed.
# 1552/20126 files processed.
# 1553/20126 files processed.
# 1554/20126 files processed.
# 1555/20126 files processed.
# 1556/20126 files processed.
# 1557/20126 files processed.
# 1558/20126 files processed.
# 1559/20126 files processed.
# 1560/20126 files processed.
# 1561/20126 files processed.
# 1562/20126 files processed.
# 1563/20126 files processed.
# 1564/20126 files processed.
# 1565/20126 files processed.
# 1566/20126 files processed.
# 1567/20126 files processed.
# 1568/20126 files processed.
# 1569/20126 files processed.
# 1570/20126 files processed.
# 1571/20126 files processed.
# 1572/20126 files processed.
# 1573/20126 files processed.
# 1574/20126 files processed.
# 1575/20126 files processed.
# 1576/20126 files processed.
# 1577/20126 files processed.
# 1578/20126 files processed.
# 1579/20126 files processed.
# 1580/20126 files processed.
# 1581/20126 files processed.
# 1582/20126 files processed.
# 1583/20126 files processed.
# 1584/20126 files processed.
# 1585/20126 files processed.
# 1586/20126 files processed.
# 1587/20126 files processed.
# 1588/20126 files processed.
# 1589/20126 files processed.
# 1590/20126 files processed.
# 1591/20126 files processed.
# 1592/20126 files processed.
# 1593/20126 files processed.
# 1594/20126 files processed.
# 1595/20126 files processed.
# 1596/20126 files processed.
# 1597/20126 files processed.
# 1598/20126 files processed.
# 1599/20126 files processed.
# 1600/20126 files processed.
# 1601/20126 files processed.
# 1602/20126 files processed.
# 1603/20126 files processed.
# 1604/20126 files processed.
# 1605/20126 files processed.
# 1606/20126 files processed.
# 1607/20126 files processed.
# 1608/20126 files processed.
# 1609/20126 files processed.
# 1610/20126 files processed.
# 1611/20126 files processed.
# 1612/20126 files processed.
# 1613/20126 files processed.
# 1614/20126 files processed.
# 1615/20126 files processed.
# 1616/20126 files processed.
# 1617/20126 files processed.
# 1618/20126 files processed.
# 1619/20126 files processed.
# 1620/20126 files processed.
# 1621/20126 files processed.
# 1622/20126 files processed.
# 1623/20126 files processed.
# 1624/20126 files processed.
# 1625/20126 files processed.
# 1626/20126 files processed.
# 1627/20126 files processed.
# 1628/20126 files processed.
# 1629/20126 files processed.
# 1630/20126 files processed.
# 1631/20126 files processed.
# 1632/20126 files processed.
# 1633/20126 files processed.
# 1634/20126 files processed.
# 1635/20126 files processed.
# 1636/20126 files processed.
# 1637/20126 files processed.
# 1638/20126 files processed.
# 1639/20126 files processed.
# 1640/20126 files processed.
# 1641/20126 files processed.
# 1642/20126 files processed.
# 1643/20126 files processed.
# 1644/20126 files processed.
# 1645/20126 files processed.
# 1646/20126 files processed.
# 1647/20126 files processed.
# 1648/20126 files processed.
# 1649/20126 files processed.
# 1650/20126 files processed.
# 1651/20126 files processed.
# 1652/20126 files processed.
# 1653/20126 files processed.
# 1654/20126 files processed.
# 1655/20126 files processed.
# 1656/20126 files processed.
# 1657/20126 files processed.
# 1658/20126 files processed.
# 1659/20126 files processed.
# 1660/20126 files processed.
# 1661/20126 files processed.
# 1662/20126 files processed.
# 1663/20126 files processed.
# 1664/20126 files processed.
# 1665/20126 files processed.
# 1666/20126 files processed.
# 1667/20126 files processed.
# 1668/20126 files processed.
# 1669/20126 files processed.
# 1670/20126 files processed.
# 1671/20126 files processed.
# 1672/20126 files processed.
# 1673/20126 files processed.
# 1674/20126 files processed.
# 1675/20126 files processed.
# 1676/20126 files processed.
# 1677/20126 files processed.
# 1678/20126 files processed.
# 1679/20126 files processed.
# 1680/20126 files processed.
# 1681/20126 files processed.
# 1682/20126 files processed.
# 1683/20126 files processed.
# 1684/20126 files processed.
# 1685/20126 files processed.
# 1686/20126 files processed.
# 1687/20126 files processed.
# 1688/20126 files processed.
# 1689/20126 files processed.
# 1690/20126 files processed.
# 1691/20126 files processed.
# 1692/20126 files processed.
# 1693/20126 files processed.
# 1694/20126 files processed.
# 1695/20126 files processed.
# 1696/20126 files processed.
# 1697/20126 files processed.
# 1698/20126 files processed.
# 1699/20126 files processed.
# 1700/20126 files processed.
# 1701/20126 files processed.
# 1702/20126 files processed.
# 1703/20126 files processed.
# 1704/20126 files processed.
# 1705/20126 files processed.
# 1706/20126 files processed.
# 1707/20126 files processed.
# 1708/20126 files processed.
# 1709/20126 files processed.
# 1710/20126 files processed.
# 1711/20126 files processed.
# 1712/20126 files processed.
# 1713/20126 files processed.
# 1714/20126 files processed.
# 1715/20126 files processed.
# 1716/20126 files processed.
# 1717/20126 files processed.
# 1718/20126 files processed.
# 1719/20126 files processed.
# 1720/20126 files processed.
# 1721/20126 files processed.
# 1722/20126 files processed.
# 1723/20126 files processed.
# 1724/20126 files processed.
# 1725/20126 files processed.
# 1726/20126 files processed.
# 1727/20126 files processed.
# 1728/20126 files processed.
# 1729/20126 files processed.
# 1730/20126 files processed.
# 1731/20126 files processed.
# 1732/20126 files processed.
# 1733/20126 files processed.
# 1734/20126 files processed.
# 1735/20126 files processed.
# 1736/20126 files processed.
# 1737/20126 files processed.
# 1738/20126 files processed.
# 1739/20126 files processed.
# 1740/20126 files processed.
# 1741/20126 files processed.
# 1742/20126 files processed.
# 1743/20126 files processed.
# 1744/20126 files processed.
# 1745/20126 files processed.
# 1746/20126 files processed.
# 1747/20126 files processed.
# 1748/20126 files processed.
# 1749/20126 files processed.
# 1750/20126 files processed.
# 1751/20126 files processed.
# 1752/20126 files processed.
# ...
# 5623/20126 files processed.
# 5624/20126 files processed.
# 5625/20126 files processed.
# 5626/20126 files processed.
# 5627/20126 files processed.
# 5628/20126 files processed.
# 5629/20126 files processed.
# 5630/20126 files processed.
# 5631/20126 files processed.
# 5632/20126 files processed.
# 5633/20126 files processed.
# 5634/20126 files processed.
# 5635/20126 files processed.
# 5636/20126 files processed.
# 5637/20126 files processed.
# 5638/20126 files processed.
# 5639/20126 files processed.
# 5640/20126 files processed.
# 5641/20126 files processed.
# 5642/20126 files processed.
# 5643/20126 files processed.
# 5644/20126 files processed.
# 5645/20126 files processed.
# 5646/20126 files processed.
# 5647/20126 files processed.
# 5648/20126 files processed.
# 5649/20126 files processed.
# 5650/20126 files processed.
# 5651/20126 files processed.
# 5652/20126 files processed.
# 5653/20126 files processed.
# 5654/20126 files processed.
# 5655/20126 files processed.
# 5656/20126 files processed.
# 5657/20126 files processed.
# 5658/20126 files processed.
# 5659/20126 files processed.
# 5660/20126 files processed.
# 5661/20126 files processed.
# 5662/20126 files processed.
# 5663/20126 files processed.
# 5664/20126 files processed.
# 5665/20126 files processed.
# 5666/20126 files processed.
# 5667/20126 files processed.
# 5668/20126 files processed.
# 5669/20126 files processed.
# 5670/20126 files processed.
# 5671/20126 files processed.
# 5672/20126 files processed.
# 5673/20126 files processed.
# 5674/20126 files processed.
# 5675/20126 files processed.
# 5676/20126 files processed.
# 5677/20126 files processed.
# 5678/20126 files processed.
# 5679/20126 files processed.
# 5680/20126 files processed.
# 5681/20126 files processed.
# 5682/20126 files processed.
# 5683/20126 files processed.
# 5684/20126 files processed.
# 5685/20126 files processed.
# 5686/20126 files processed.
# 5687/20126 files processed.
# 5688/20126 files processed.
# 5689/20126 files processed.
# 5690/20126 files processed.
# 5691/20126 files processed.
# 5692/20126 files processed.
# 5693/20126 files processed.
# 5694/20126 files processed.
# 5695/20126 files processed.
# 5696/20126 files processed.
# 5697/20126 files processed.
# 5698/20126 files processed.
# 5699/20126 files processed.
# 5700/20126 files processed.
# 5701/20126 files processed.
# 5702/20126 files processed.
# 5703/20126 files processed.
# 5704/20126 files processed.
# 5705/20126 files processed.
# 5706/20126 files processed.
# 5707/20126 files processed.
# 5708/20126 files processed.
# 5709/20126 files processed.
# 5710/20126 files processed.
# 5711/20126 files processed.
# 5712/20126 files processed.
# 5713/20126 files processed.
# 5714/20126 files processed.
# 5715/20126 files processed.
# 5716/20126 files processed.
# 5717/20126 files processed.
# 5718/20126 files processed.
# 5719/20126 files processed.
# 5720/20126 files processed.
# 5721/20126 files processed.
# 5722/20126 files processed.
# 5723/20126 files processed.
# 5724/20126 files processed.
# 5725/20126 files processed.
# 5726/20126 files processed.
# 5727/20126 files processed.
# 5728/20126 files processed.
# 5729/20126 files processed.
# 5730/20126 files processed.
# 5731/20126 files processed.
# 5732/20126 files processed.
# 5733/20126 files processed.
# 5734/20126 files processed.
# 5735/20126 files processed.
# 5736/20126 files processed.
# 5737/20126 files processed.
# 5738/20126 files processed.
# 5739/20126 files processed.
# 5740/20126 files processed.
# 5741/20126 files processed.
# 5742/20126 files processed.
# 5743/20126 files processed.
# 5744/20126 files processed.
# 5745/20126 files processed.
# 5746/20126 files processed.
# 5747/20126 files processed.
# 5748/20126 files processed.
# 5749/20126 files processed.
# 5750/20126 files processed.
# 5751/20126 files processed.
# 5752/20126 files processed.
# 5753/20126 files processed.
# 5754/20126 files processed.
# 5755/20126 files processed.
# 5756/20126 files processed.
# 5757/20126 files processed.
# 5758/20126 files processed.
# 5759/20126 files processed.
# 5760/20126 files processed.
# 5761/20126 files processed.
# 5762/20126 files processed.
# 5763/20126 files processed.
# 5764/20126 files processed.
# 5765/20126 files processed.
# 5766/20126 files processed.
# 5767/20126 files processed.
# 5768/20126 files processed.
# 5769/20126 files processed.
# 5770/20126 files processed.
# 5771/20126 files processed.
# 5772/20126 files processed.
# 5773/20126 files processed.
# 5774/20126 files processed.
# 5775/20126 files processed.
# 5776/20126 files processed.
# 5777/20126 files processed.
# 5778/20126 files processed.
# 5779/20126 files processed.
# 5780/20126 files processed.
# 5781/20126 files processed.
# 5782/20126 files processed.
# 5783/20126 files processed.
# 5784/20126 files processed.
# 5785/20126 files processed.
# 5786/20126 files processed.
# 5787/20126 files processed.
# 5788/20126 files processed.
# 5789/20126 files processed.
# 5790/20126 files processed.
# 5791/20126 files processed.
# 5792/20126 files processed.
# 5793/20126 files processed.
# 5794/20126 files processed.
# 5795/20126 files processed.
# 5796/20126 files processed.
# 5797/20126 files processed.
# 5798/20126 files processed.
# 5799/20126 files processed.
# 5800/20126 files processed.
# 5801/20126 files processed.
# 5802/20126 files processed.
# 5803/20126 files processed.
# 5804/20126 files processed.
# 5805/20126 files processed.
# 5806/20126 files processed.
# 5807/20126 files processed.
# 5808/20126 files processed.
# 5809/20126 files processed.
# 5810/20126 files processed.
# 5811/20126 files processed.
# 5812/20126 files processed.
# 5813/20126 files processed.
# 5814/20126 files processed.
# 5815/20126 files processed.
# 5816/20126 files processed.
# 5817/20126 files processed.
# 5818/20126 files processed.
# 5819/20126 files processed.
# 5820/20126 files processed.
# 5821/20126 files processed.
# 5822/20126 files processed.
# 5823/20126 files processed.
# 5824/20126 files processed.
# 5825/20126 files processed.
# 5826/20126 files processed.
# 5827/20126 files processed.
# 5828/20126 files processed.
# 5829/20126 files processed.
# 5830/20126 files processed.
# 5831/20126 files processed.
# 5832/20126 files processed.
# 5833/20126 files processed.
# 5834/20126 files processed.
# 5835/20126 files processed.
# 5836/20126 files processed.
# 5837/20126 files processed.
# 5838/20126 files processed.
# 5839/20126 files processed.
# 5840/20126 files processed.
# 5841/20126 files processed.
# 5842/20126 files processed.
# 5843/20126 files processed.
# 5844/20126 files processed.
# 5845/20126 files processed.
# 5846/20126 files processed.
# 5847/20126 files processed.
# 5848/20126 files processed.
# 5849/20126 files processed.
# 5850/20126 files processed.
# 5851/20126 files processed.
# 5852/20126 files processed.
# 5853/20126 files processed.
# 5854/20126 files processed.
# 5855/20126 files processed.
# 5856/20126 files processed.
# 5857/20126 files processed.
# 5858/20126 files processed.
# 5859/20126 files processed.
# 5860/20126 files processed.
# 5861/20126 files processed.
# 5862/20126 files processed.
# 5863/20126 files processed.
# 5864/20126 files processed.
# 5865/20126 files processed.
# 5866/20126 files processed.
# 5867/20126 files processed.
# 5868/20126 files processed.
# 5869/20126 files processed.
# 5870/20126 files processed.
# 5871/20126 files processed.
# 5872/20126 files processed.
# 5873/20126 files processed.
# 5874/20126 files processed.
# 5875/20126 files processed.
# 5876/20126 files processed.
# 5877/20126 files processed.
# 5878/20126 files processed.
# 5879/20126 files processed.
# 5880/20126 files processed.
# 5881/20126 files processed.
# 5882/20126 files processed.
# 5883/20126 files processed.
# 5884/20126 files processed.
# 5885/20126 files processed.
# 5886/20126 files processed.
# 5887/20126 files processed.
# 5888/20126 files processed.
# 5889/20126 files processed.
# 5890/20126 files processed.
# 5891/20126 files processed.
# 5892/20126 files processed.
# 5893/20126 files processed.
# 5894/20126 files processed.
# 5895/20126 files processed.
# 5896/20126 files processed.
# 5897/20126 files processed.
# 5898/20126 files processed.
# 5899/20126 files processed.
# 5900/20126 files processed.
# 5901/20126 files processed.
# 5902/20126 files processed.
# 5903/20126 files processed.
# 5904/20126 files processed.
# 5905/20126 files processed.
# 5906/20126 files processed.
# 5907/20126 files processed.
# 5908/20126 files processed.
# 5909/20126 files processed.
# 5910/20126 files processed.
# 5911/20126 files processed.
# 5912/20126 files processed.
# 5913/20126 files processed.
# 5914/20126 files processed.
# 5915/20126 files processed.
# 5916/20126 files processed.
# 5917/20126 files processed.
# 5918/20126 files processed.
# 5919/20126 files processed.
# 5920/20126 files processed.
# 5921/20126 files processed.
# 5922/20126 files processed.
# 5923/20126 files processed.
# 5924/20126 files processed.
# 5925/20126 files processed.
# 5926/20126 files processed.
# 5927/20126 files processed.
# 5928/20126 files processed.
# 5929/20126 files processed.
# 5930/20126 files processed.
# 5931/20126 files processed.
# 5932/20126 files processed.
# 5933/20126 files processed.
# 5934/20126 files processed.
# 5935/20126 files processed.
# 5936/20126 files processed.
# 5937/20126 files processed.
# 5938/20126 files processed.
# 5939/20126 files processed.
# 5940/20126 files processed.
# 5941/20126 files processed.
# 5942/20126 files processed.
# 5943/20126 files processed.
# 5944/20126 files processed.
# 5945/20126 files processed.
# 5946/20126 files processed.
# 5947/20126 files processed.
# 5948/20126 files processed.
# 5949/20126 files processed.
# 5950/20126 files processed.
# 5951/20126 files processed.
# 5952/20126 files processed.
# 5953/20126 files processed.
# 5954/20126 files processed.
# 5955/20126 files processed.
# 5956/20126 files processed.
# 5957/20126 files processed.
# 5958/20126 files processed.
# 5959/20126 files processed.
# 5960/20126 files processed.
# 5961/20126 files processed.
# 5962/20126 files processed.
# 5963/20126 files processed.
# 5964/20126 files processed.
# 5965/20126 files processed.
# 5966/20126 files processed.
# 5967/20126 files processed.
# 5968/20126 files processed.
# 5969/20126 files processed.
# 5970/20126 files processed.
# 5971/20126 files processed.
# 5972/20126 files processed.
# 5973/20126 files processed.
# 5974/20126 files processed.
# 5975/20126 files processed.
# 5976/20126 files processed.
# 5977/20126 files processed.
# 5978/20126 files processed.
# 5979/20126 files processed.
# 5980/20126 files processed.
# 5981/20126 files processed.
# 5982/20126 files processed.
# 5983/20126 files processed.
# 5984/20126 files processed.
# 5985/20126 files processed.
# 5986/20126 files processed.
# 5987/20126 files processed.
# 5988/20126 files processed.
# 5989/20126 files processed.
# 5990/20126 files processed.
# 5991/20126 files processed.
# 5992/20126 files processed.
# 5993/20126 files processed.
# 5994/20126 files processed.
# 5995/20126 files processed.
# 5996/20126 files processed.
# 5997/20126 files processed.
# 5998/20126 files processed.
# 5999/20126 files processed.
# 6000/20126 files processed.
# 6001/20126 files processed.
# 6002/20126 files processed.
# 6003/20126 files processed.
# 6004/20126 files processed.
# 6005/20126 files processed.
# 6006/20126 files processed.
# 6007/20126 files processed.
# 6008/20126 files processed.
# 6009/20126 files processed.
# 6010/20126 files processed.
# 6011/20126 files processed.
# 6012/20126 files processed.
# 6013/20126 files processed.
# 6014/20126 files processed.
# 6015/20126 files processed.
# 6016/20126 files processed.
# 6017/20126 files processed.
# 6018/20126 files processed.
# 6019/20126 files processed.
# 6020/20126 files processed.
# 6021/20126 files processed.
# 6022/20126 files processed.
# 6023/20126 files processed.
# 6024/20126 files processed.
# 6025/20126 files processed.
# 6026/20126 files processed.
# 6027/20126 files processed.
# 6028/20126 files processed.
# 6029/20126 files processed.
# 6030/20126 files processed.
# 6031/20126 files processed.
# 6032/20126 files processed.
# 6033/20126 files processed.
# 6034/20126 files processed.
# 6035/20126 files processed.
# 6036/20126 files processed.
# 6037/20126 files processed.
# 6038/20126 files processed.
# 6039/20126 files processed.
# 6040/20126 files processed.
# 6041/20126 files processed.
# 6042/20126 files processed.
# 6043/20126 files processed.
# 6044/20126 files processed.
# 6045/20126 files processed.
# 6046/20126 files processed.
# 6047/20126 files processed.
# 6048/20126 files processed.
# 6049/20126 files processed.
# 6050/20126 files processed.
# 6051/20126 files processed.
# 6052/20126 files processed.
# 6053/20126 files processed.
# 6054/20126 files processed.
# 6055/20126 files processed.
# 6056/20126 files processed.
# 6057/20126 files processed.
# 6058/20126 files processed.
# 6059/20126 files processed.
# 6060/20126 files processed.
# 6061/20126 files processed.
# 6062/20126 files processed.
# 6063/20126 files processed.
# 6064/20126 files processed.
# 6065/20126 files processed.
# 6066/20126 files processed.
# 6067/20126 files processed.
# 6068/20126 files processed.
# 6069/20126 files processed.
# 6070/20126 files processed.
# 6071/20126 files processed.
# 6072/20126 files processed.
# 6073/20126 files processed.
# 6074/20126 files processed.
# 6075/20126 files processed.
# 6076/20126 files processed.
# 6077/20126 files processed.
# 6078/20126 files processed.
# 6079/20126 files processed.
# 6080/20126 files processed.
# 6081/20126 files processed.
# 6082/20126 files processed.
# 6083/20126 files processed.
# 6084/20126 files processed.
# 6085/20126 files processed.
# 6086/20126 files processed.
# 6087/20126 files processed.
# 6088/20126 files processed.
# 6089/20126 files processed.
# 6090/20126 files processed.
# 6091/20126 files processed.
# 6092/20126 files processed.
# 6093/20126 files processed.
# 6094/20126 files processed.
# 6095/20126 files processed.
# 6096/20126 files processed.
# 6097/20126 files processed.
# 6098/20126 files processed.
# 6099/20126 files processed.
# 6100/20126 files processed.
# 6101/20126 files processed.
# 6102/20126 files processed.
# 6103/20126 files processed.
# 6104/20126 files processed.
# 6105/20126 files processed.
# 6106/20126 files processed.
# 6107/20126 files processed.
# 6108/20126 files processed.
# 6109/20126 files processed.
# 6110/20126 files processed.
# 6111/20126 files processed.
# 6112/20126 files processed.
# 6113/20126 files processed.
# 6114/20126 files processed.
# 6115/20126 files processed.
# 6116/20126 files processed.
# 6117/20126 files processed.
# 6118/20126 files processed.
# 6119/20126 files processed.
# 6120/20126 files processed.
# 6121/20126 files processed.
# 6122/20126 files processed.
# 6123/20126 files processed.
# 6124/20126 files processed.
# 6125/20126 files processed.
# 6126/20126 files processed.
# 6127/20126 files processed.
# 6128/20126 files processed.
# 6129/20126 files processed.
# 6130/20126 files processed.
# 6131/20126 files processed.
# 6132/20126 files processed.
# 6133/20126 files processed.
# 6134/20126 files processed.
# 6135/20126 files processed.
# 6136/20126 files processed.
# 6137/20126 files processed.
# 6138/20126 files processed.
# 6139/20126 files processed.
# 6140/20126 files processed.
# 6141/20126 files processed.
# 6142/20126 files processed.
# 6143/20126 files processed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8515960ed09b> in <module>()
#      97
#      98 if __name__ == "__main__":
# ---> 99     main()
#
# <ipython-input-4-8515960ed09b> in main()
#      91
#      92     #process_data(cur, conn, filepath='data/games', filetype='*.csv', func=process_games_file)
# ---> 93     process_data(cur, conn, filepath='data/reviews', filetype='*.json', func=process_reviews_file)
#      94
#      95     conn.close()
#
# <ipython-input-4-8515960ed09b> in process_data(cur, conn, filepath, filetype, func)
#      79     # iterate over files and process
#      80     for i, datafile in enumerate(all_files, 1):
# ---> 81         func(cur, datafile)
#      82         conn.commit()
#      83         print('{}/{} files processed.'.format(i, num_files))
#
# <ipython-input-4-8515960ed09b> in process_reviews_file(cur, filepath)
#      59
#      60     for i, row in review_authors_data.iterrows():
# ---> 61         cur.execute(review_authors_table_insert, row)
#      62
#      63 def process_data(cur, conn, filepath, filetype, func):
#
# /opt/conda/lib/python3.6/encodings/utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
# %load_ext sql
# %sql postgresql://student:student@127.0.0.1/steam_reviews
# Out:
# 'Connected: student@steam_reviews'

# %%
# %sql SELECT * FROM review_authors LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/steam_reviews
# 5 rows affected.
# [('76561198166181344', '13232092', 1, 1, '517', '0', '354', datetime.datetime(2014, 12, 12, 2, 52, 37)),
#  ('76561198078179613', '13232081', 169, 27, '396', '0', '207', datetime.datetime(2016, 2, 15, 2, 5, 5)),
#  ('76561198134106125', '13232080', 131, 2, '8674', '0', '2644', datetime.datetime(2019, 6, 2, 23, 58, 4)),
#  ('76561198134910006', '13232078', 65, 2, '40235', '0', '3162', datetime.datetime(2022, 7, 7, 5, 10, 48)),
#  ('76561198118603999', '13232004', 100, 3, '14103', '0', '5239', datetime.datetime(2022, 7, 25, 4, 4, 47))]

# %%
# %sql SELECT count(*) FROM reviews
# Out:
#  * postgresql://student:***@127.0.0.1/steam_reviews
# 1 rows affected.
# [(614283,)]
